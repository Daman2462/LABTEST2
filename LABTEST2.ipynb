# %%
import pandas as pd
import numpy as np
 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split


d = load_diabetes()

d['feature_names']
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
df=pd.DataFrame(d.data ,columns = d['feature_names'])
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
plt.hist(df['age'])
# Out:
# (array([24., 27., 54., 49., 60., 85., 71., 46., 21.,  5.]),
#  array([-0.10722563, -0.0854304 , -0.06363517, -0.04183994, -0.02004471,
#          0.00175052,  0.02354575,  0.04534098,  0.06713621,  0.08893144,
#          0.11072668]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #  AGE VS BMI

# %%
plt.scatter(df['age'],df['bmi'])

# %%
plt.scatter(df['bmi'],df['bp'])

# %%
x=d['data']
y=d['target']




X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.6 )
# Out:
# (442, 10) (442,)

# %%
df.isnull()
# Out:
#        age    sex    bmi     bp     s1     s2     s3     s4     s5     s6
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 437  False  False  False  False  False  False  False  False  False  False
# 438  False  False  False  False  False  False  False  False  False  False
# 439  False  False  False  False  False  False  False  False  False  False
# 440  False  False  False  False  False  False  False  False  False  False
# 441  False  False  False  False  False  False  False  False  False  False
#
# [442 rows x 10 columns]

# %%
import sklearn 
dir(sklearn.neighbors)
# Out:
# ['BallTree',
#  'KDTree',
#  'KNeighborsClassifier',
#  'KNeighborsRegressor',
#  'KNeighborsTransformer',
#  'KernelDensity',
#  'LocalOutlierFactor',
#  'NearestCentroid',
#  'NearestNeighbors',
#  'NeighborhoodComponentsAnalysis',
#  'RadiusNeighborsClassifier',
#  'RadiusNeighborsRegressor',
#  'RadiusNeighborsTransformer',
#  'VALID_METRICS',
#  'VALID_METRICS_SPARSE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_ball_tree',
#  '_base',
#  '_classification',
#  '_graph',
#  '_kd_tree',
#  '_kde',
#  '_lof',
#  '_nca',
#  '_nearest_centroid',
#  '_partition_nodes',
#  '_regression',
#  '_unsupervised',
#  'kneighbors_graph',
#  'radius_neighbors_graph',
#  'sort_graph_by_row_values']

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(n_neighbors=2)

neigh.fit(X_train,y_train)

pred = neigh.predict(X_test )
pred
# Out:
# array([141., 244.,  88., 155., 135.,  65., 122.,  72., 146., 113.,  59.,
#        198., 110.,  52., 195., 110., 164., 206.,  48.,  59., 164., 235.,
#        144.,  52.,  54., 151., 219., 111., 185.,  87., 148., 142.,  78.,
#        166., 101.,  53.,  75.,  25.,  25., 191.,  71., 163., 164.,  53.,
#         97., 244.,  42.,  71., 122.,  25., 151., 202.,  89.,  53., 198.,
#        132.,  72.,  25., 198., 141., 195., 220., 225., 198., 134., 142.,
#        220.,  31.,  85.,  71., 198.,  25., 104.,  31.,  63., 164.,  75.,
#         71.,  52., 225.,  42.,  48., 252., 110., 259.,  84.,  84., 151.,
#        259., 125., 163.,  64.,  69.,  39., 275., 131., 139., 144.,  49.,
#        127.,  77., 225., 230.,  75., 102., 279.,  77.,  66.,  47.,  68.,
#         68., 128., 101., 118.,  64.,  97.,  55., 121., 118.,  87., 212.,
#         60., 275., 182.,  58., 214.,  44., 229.,  71., 150., 280., 233.,
#        131.,  93., 281., 182., 192.,  88.,  63., 281., 113., 131.,  50.,
#         55., 140., 302.,  51., 109., 141., 126., 202., 150., 137.,  51.,
#        107., 189.])

# %%
from sklearn.metrics import accuracy_score,recall_score,r2_score

# %%
accuracy_score(y_test, pred)
# Out:
# 0.011235955056179775

# %%
r2_score(y_test, pred)
# Out:
# -0.06108059264410892

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2 ,random_state =24)
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=2)

neigh.fit(X_train,y_train)

pred = neigh.predict(X_test )
pred

accuracy_score(y_test, pred)*100
y_test, pred
# Out:
# (array([ 89.,  59., 128.,  53., 168., 206., 202.,  59.,  88., 158., 138.,
#         172., 147., 295.,  71., 196., 118.,  65., 214.,  48., 259.,  49.,
#          91.,  72., 257., 199., 189.,  74., 128.,  70.,  52.,  39., 209.,
#         283., 259., 114.,  95., 129., 235., 170.,  51., 180.,  68.,  49.,
#          78., 202.,  99., 292., 120., 139., 200., 175., 249.,  88.,  95.,
#         179.,  96., 185.,  42.,  37., 151., 311., 222., 276.,  98.,  79.,
#          45.,  75.,  84., 192., 141.,  71., 275.,  59.,  85., 144., 191.,
#         202.,  96., 243., 191., 143., 101., 100., 265., 172., 190.,  60.,
#          42.]),
#  array([ 63.,  63., 242.,  83., 115., 146.,  61.,  81., 135.,  73.,  49.,
#          55., 129., 277.,  71.,  69.,  65.,  63.,  93.,  85., 122.,  72.,
#         144.,  59.,  77.,  71., 190.,  42., 275., 141.,  75.,  87., 111.,
#          66., 174.,  65., 115.,  91.,  91.,  67.,  97., 115., 113.,  72.,
#          47., 219.,  85., 181., 212., 111.,  55., 113., 122.,  97., 142.,
#         107.,  53., 150.,  39.,  84., 141., 122., 122.,  88.,  84., 135.,
#          39.,  91., 107., 164.,  67.,  53., 163.,  90.,  53., 126., 166.,
#          69.,  53., 248.,  60.,  97.,  58., 122., 185.,  81., 150.,  49.,
#          63.]))

# %%
r2_score(y_test, pred)
# Out:
# -0.13977499393115633

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.6 ,random_state =24)
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=2)

neigh.fit(X_train,y_train)

pred = neigh.predict(X_test )
pred

accuracy_score(y_test, pred)*100
# Out:
# 0.7518796992481203

# %%
r2_score(y_test, pred)
# Out:
# -0.06108059264410892

# %%
for i in range(1,7):
    plt.hist(df['s'+str(i)])

# %%
plt.scatter(df['bmi'],df['s1'])

# %%
plt.scatter(df['bmi'],df['s2'])

# %%
plt.scatter(df['sex'],df['s2'])

# %%
from sklearn.metrics import recall_score,r2_score
